# %% [markdown]
# ## Netflix Data Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Netflix_data_analysis.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.size
# Out:
# 85679

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.shape
# Out:
# (7787, 11)

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %%
df["Director"].fillna(df["Director"].mode()[0],inplace=True)

# %%
df["Cast"].fillna(df["Cast"].mode()[0],inplace=True)

# %%
df["Country"].fillna(df["Country"].mode()[0],inplace=True)

# %%
df["Release_Date"].fillna(df["Release_Date"].mode()[0],inplace=True)

# %%
df["Rating"].fillna(df["Rating"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   Show_Id Category  Title                Director  \
# 0      s1  TV Show     3%  Raúl Campos, Jan Suter
# 1      s2    Movie  07:19       Jorge Michel Grau
# 2      s3    Movie  23:59            Gilbert Chan
# 3      s4    Movie      9             Shane Acker
# 4      s5    Movie     21          Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df[df["Title"].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df["Date"] = pd.to_datetime(df["Release_Date"])

# %%
df.head(2)
# Out:
#   Show_Id Category  Title                Director  \
# 0      s1  TV Show     3%  Raúl Campos, Jan Suter
# 1      s2    Movie  07:19       Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
df["Date"].dt.year.value_counts()
# Out:
# 2019    2153
# 2020    2019
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: Date, dtype: int64

# %%
df["Date"].dt.year.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
ax = sns.countplot(x="Category",data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df["Year"] = df["Date"].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title                Director  \
# 0      s1  TV Show     3%  Raúl Campos, Jan Suter
# 1      s2    Movie  07:19       Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016

# %%
sns.set(rc={'figure.figsize':(10,5)})
ax = sns.countplot(x="Year",data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df[ (df["Category"]=='Movie') & (df["Type"]=='Comedies') ]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
df[(df["Category"]=='Movie') & (df["Type"]=='Comedies') | (df["Country"]=='United States')]
# Out:
#      Show_Id Category              Title                Director  \
# 3         s4    Movie                  9             Shane Acker
# 4         s5    Movie                 21          Robert Luketic
# 7         s8    Movie                187          Kevin Reynolds
# 10       s11    Movie               1922            Zak Hilditch
# 14       s15    Movie               3022              John Suits
# ...      ...      ...                ...                     ...
# 7776   s7775    Movie             Zodiac           David Fincher
# 7779   s7778  TV Show        Zombie Dumb  Raúl Campos, Jan Suter
# 7780   s7779    Movie         Zombieland         Ruben Fleischer
# 7783   s7782    Movie               Zoom            Peter Hewitt
# 7786   s7785    Movie  Zulu Man in Japan  Raúl Campos, Jan Suter
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %%
df[df["Cast"].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       Date  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %%
df[df["Cast"].str.contains("Chris Hemsworth")]
# Out:
#      Show_Id Category                   Title                  Director  \
# 635     s636    Movie  Avengers: Infinity War  Anthony Russo, Joe Russo
# 2071   s2072    Movie              Extraction              Sam Hargrave
# 7060   s7059    Movie          Thor: Ragnarok             Taika Waititi
#
#                                                    Cast        Country  \
# 635   Robert Downey Jr., Josh Brolin, Mark Ruffalo, ...  United States
# 2071  Chris Hemsworth, Rudhraksh Jaiswal, Randeep Ho...  United States
# 7060  Chris Hemsworth, Tom Hiddleston, Cate Blanchet...  United States
#
#            Release_Date Rating Duration  \
# 635   December 25, 2018  PG-13  150 min
# 2071     April 24, 2020      R  117 min
# 7060       June 5, 2018  PG-13  131 min
#
#                                                 Type  \
# 635             Action & Adventure, Sci-Fi & Fantasy
# 2071                              Action & Adventure
# 7060  Action & Adventure, Comedies, Sci-Fi & Fantasy
#
# ...

# %%
df.Rating.nunique()
# Out:
# 14

# %%
df["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y',
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df[(df["Category"]=="Movie") & (df["Rating"]=="TV-14") & (df["Country"]=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
df[(df["Category"]=="Movie") & (df["Rating"]=="R") & (df["Year"]==2018)]
# Out:
#      Show_Id Category                       Title                   Director  \
# 2         s3    Movie                       23:59               Gilbert Chan
# 17       s18    Movie                      22-Jul            Paul Greengrass
# 89       s90    Movie            24 Hours to Live                 Brian Smrz
# 126     s127    Movie                      6 Days                 Toa Fraser
# 166     s167    Movie           A Dangerous Woman         Stephen Gyllenhaal
# ...      ...      ...                         ...                        ...
# 7381   s7380    Movie              V for Vendetta             James McTeigue
# 7574   s7573    Movie        What's Up With Love?  Rudy Soedjarwo, Riri Riza
# 7590   s7589    Movie           Where's the Money            Scott Zabielski
# 7643   s7642    Movie             Wish I Was Here                 Zach Braff
# 7760   s7759    Movie  Zack and Miri Make a Porno                Kevin Smith
#
# ...

# %%
df[(df["Category"]=="Movie") & (df["Rating"]=="PG-13")]
# Out:
#      Show_Id Category                    Title         Director  \
# 3         s4    Movie                        9      Shane Acker
# 4         s5    Movie                       21   Robert Luketic
# 44       s45    Movie                 Æon Flux     Karyn Kusama
# 50       s51    Movie              10,000 B.C.  Roland Emmerich
# 71       s72    Movie                16 Blocks   Richard Donner
# ...      ...      ...                      ...              ...
# 7683   s7682    Movie               Wyatt Earp  Lawrence Kasdan
# 7690   s7689    Movie                      XXx        Rob Cohen
# 7691   s7690    Movie  XXX: State of the Union     Lee Tamahori
# 7707   s7706    Movie                  Yes Man      Peyton Reed
# 7716   s7715    Movie              Yoga Hosers      Kevin Smith
#
#                                                    Cast  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df[(df["Category"]=="Movie") & (df["Rating"]=="PG")]
# Out:
#      Show_Id Category                               Title  \
# 145     s146    Movie                        A 2nd Chance
# 151     s152    Movie                     A Boy Called Po
# 153     s154    Movie                    A Bridge Too Far
# 163     s164    Movie                  A Cinderella Story
# 164     s165    Movie  A Cinderella Story: Christmas Wish
# ...      ...      ...                                 ...
# 7661   s7660    Movie                    Woody Woodpecker
# 7706   s7705    Movie                          Yellowbird
# 7747   s7746    Movie                Yours, Mine and Ours
# 7778   s7777    Movie                            Zokkomon
# 7783   s7782    Movie                                Zoom
#
#                   Director                                               Cast  \
# 145              Clay Glen  Nina Pearce, Adam Tuominen, Emily Morris, Amy ...
# 151             John Asher  Christopher Gorham, Julian Feder, Kaitlin Doub...
# ...

# %%
ax = sns.countplot(x="Rating",data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df[['Minute','Unit']]=df['Duration'].str.split(' ',expand=True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title                Director  \
# 0      s1  TV Show     3%  Raúl Campos, Jan Suter
# 1      s2    Movie  07:19       Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description       Date  Year Minute  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020      4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016     93
#
#       Unit
# 0  Seasons
# 1      min

# %%
df_tv_shows = df[df["Category"]=="TV Show"]
df_tv_shows.head(2)
# Out:
#   Show_Id Category Title                Director  \
# 0      s1  TV Show    3%  Raúl Campos, Jan Suter
# 5      s6  TV Show    46             Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description       Date  Year Minute  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020      4
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017      1
#
#       Unit
# 0  Seasons
# 5   Season

# %%
df_tv_shows.Country.value_counts()
# Out:
# United States                                                982
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
df_tv_shows.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_movies = df[df["Category"]=='Movie']
df_movies.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description       Date  Year Minute  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016     93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018     78
#
#   Unit
# 1  min
# 2  min

# %%
df_movies.Country.value_counts()
# Out:
# United States                                                   2080
# India                                                            852
# United Kingdom                                                   193
# Canada                                                           118
# Spain                                                             89
#                                                                 ...
# United Kingdom, Denmark, Canada, Croatia                           1
# United States, South Korea                                         1
# Kenya, United States                                               1
# India, Turkey                                                      1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: Country, Length: 590, dtype: int64

# %%
df_movies.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.sort_values(by='Year',ascending=False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 4864   s4864    Movie            Pinkfong & Baby Shark's Space Adventure
# 2799   s2800    Movie                                               Hook
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 560     s561    Movie                                           Apaharan
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 5919   s5919    Movie                                          Surf's Up
# 5907   s5907    Movie                                           Superbad
#
#                      Director  \
# 4864            Byeon Hee-sun
# 2799         Steven Spielberg
# 5955               Aamir Khan
# 366       Francisco D'Eufemia
# ...

# %%
df[(df['Category']=='Movie') & (df["Type"]=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df[(df['Category']=='Movie') & (df["Type"]=='Dramas') | (df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title                Director  \
# 4         s5    Movie                          21          Robert Luketic
# 7         s8    Movie                         187          Kevin Reynolds
# 111     s112  TV Show                     44 Cats  Raúl Campos, Jan Suter
# 170     s171    Movie                A Family Man           Mark Williams
# 232     s233    Movie  A Stoning in Fulham County           Larry Elikann
# ...      ...      ...                         ...                     ...
# 7668   s7667  TV Show               World of Winx          Iginio Straffi
# 7717   s7716  TV Show                        Yoko  Raúl Campos, Jan Suter
# 7719   s7718  TV Show                         YOM  Raúl Campos, Jan Suter
# 7758   s7757  TV Show                          Z4  Raúl Campos, Jan Suter
# 7761   s7760  TV Show                   Zak Storm  Raúl Campos, Jan Suter
#
#                                                    Cast  \
# ...

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Date',
#        'Year', 'Minute', 'Unit'],
#       dtype='object')

# %%
sns.histplot(x=df["Category"],kde=True)
# Out:
# <Axes: xlabel='Category', ylabel='Count'>
